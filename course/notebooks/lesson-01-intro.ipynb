# %% [markdown]
# ## Exercise
# Modify `examples/hello.jusu` to accept a name from `input()` and print `Hello, <name>!`. Save your changes and re-run the cell above to verify output.

# %%
import subprocess
import sys

print('Running example: examples/hello.jusu')
try:
    r = subprocess.run([sys.executable, 'compiler/jusu.py', 'run', 'examples/hello.jusu'], capture_output=True, text=True, check=True)
    print('--- output ---')
    print(r.stdout)
except subprocess.CalledProcessError as e:
    print('Error running example:', e)
    print('stdout:', e.stdout)
    print('stderr:', e.stderr)

# %% [markdown]
# ## Setup (local)
#
# The recommended setup is to create a virtual environment and install dev dependencies. Run these commands in a terminal (not executed automatically here):
#
# ```bash
# python -m venv .venv
# .venv\Scripts\Activate.ps1  # Windows
# pip install -e .[dev]
# ```

# %% [markdown]
# # Welcome to Lesson 01 — Introduction to Jusu++
# This notebook demonstrates how to run a Jusu++ program, basic setup steps, and a short exercise to get you started.
